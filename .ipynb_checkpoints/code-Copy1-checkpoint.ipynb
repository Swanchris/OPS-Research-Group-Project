# %% [markdown]
# # $\mathcal{l}_2$ penalty method algorithm

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import time
from copy import deepcopy

# %% [markdown]
# #### Testing functions

# %%
# def alpha(k): return 2**k
# def xplus(x): return max(x,0)
# def Norm(x): return np.linalg.norm(x)

# def obj_func(x): return x[0]**2 + x[1]**2 + x[0] - x[1]
# def G(x): return np.array([1 -x[0], -x[1] ])
# def P(x,k): return obj_func(x) + (alpha(k)/2)*xplus(G(x)[0])**2 + (alpha(k)/2)*xplus(G(x)[1])**2
# def P_grad(x,k):
#     g1 = 2*x[0] + 1 - alpha(k)*xplus(1-x[0])
#     g2 = 2*x[1] - 1 - alpha(k)*xplus(-x[1])
#     return np.array( [ g1 , g2 ] )
# def stepsize(x1, x0,k): # Barzilai-Borwein step-size (quasi-newton origin)
#     nom = np.dot(x1 - x0, P_grad(x1,k) - P_grad(x0,k))
#     denom = np.linalg.norm( P_grad(x1,k) - P_grad(x0,k) )**2
#     return nom/denom
# # Note: Direction is just steepest descent
# def GD(x, lam ,k):
#     return x - lam*P_grad(x,k)
# def Descent(x, init_step, EPSILON):
#     x0 = np.array(x)
#     k = 1
#     x_list = [x0]
#     lam = init_step
#     x1 = GD(x0, lam ,k)
#     x_list.append(x1)
#     N = Norm(x1 - x0)
#     Norm_list = [N]
    
#     while N > EPSILON:
#         lam = stepsize(x1, x0, k)
#         x0 = x1
#         x1 = GD(x0, lam, k)
#         x_list.append(x1)
#         N = Norm(x1 - x0)
#         Norm_list = [N]
#         k += 1
    
#     return np.array([ x_list, Norm_list ])

# %% [markdown]
# ## The real deal

# %%
def alpha(k): return 2**k
def xplus(x): return max(x,0)
def Norm(x): return np.linalg.norm(x)

# %%
FIELDSIZE = 100
SCALE = 100

# %%
# calculate a squared norm of s - x, as in our obj func and constraints
def norm_func(s, x):
    return (s[0] - x[0])**2 + (s[1] - x[1])**2

# create a list of the squared euclidean distance from s to each point x in X
def X_norms_sqrd(s, X): return [norm_func(s,i) for i in X]

# find the largest distance
def beta(s, X): return max(X_norms_sqrd(s, X))

# create an objective function
def obj_func(s, X, b): 
    x_list = X_norms_sqrd(s,X)
    return sum(x_list) + max(x_list)

# create the g constraints
def G(s,X, b): return [ norm_func(s, X[i]) - b for i in range(len(X))]

# l2-penalty function
def P(s,X,k, b): 
    return obj_func(s,X, b) + (alpha(k)/2)*sum([ xplus(G(s,X, b)[i])**2 for i in range(len(X)) ])

def P_grad(s,X,k, b):
    s_minus_x_0 = np.array([ s[0] - X[i][0] for i in range(len(X)) ])
    G_sum_0 = np.array([ (s[0] - X[i][0])**2 - b for i in range(len(X))])
    mult_terms_0 = [xplus(s_minus_x_0[i] * G_sum_0[i]) for i in range(len(X))]
    
    g1 = 2*sum(s_minus_x_0) + 2*alpha(k)*sum( mult_terms_0)
    
    s_minus_x_1 = np.array([ s[1] - X[i][1] for i in range(len(X)) ])
    G_sum_1 = np.array([ (s[1] - X[i][1])**2 - b for i in range(len(X))])
    mult_terms_1 = [xplus(s_minus_x_1[i] * G_sum_1[i]) for i in range(len(X))]
    
    g2 = 2*sum(s_minus_x_1) + 2*alpha(k)*sum( mult_terms_1)
    
    return np.array( [g1 , g2])

# %%
def stepsize(s1, s0, X, k, b): # Barzilai-Borwein step-size (quasi-newton origin)
    nom = np.dot(s1 - s0, P_grad(s1, X ,k, b) - P_grad(s0, X ,k, b))
    denom = np.linalg.norm( P_grad(s1, X ,k, b) - P_grad(s0, X ,k, b) )**2
    return nom/denom
# Note: Direction is just steepest descent
def GD(s, X, lam ,k, b):
    return s - lam*P_grad(s, X ,k, b)

# %%
# generate FIELDSIZE random pts in R^2 \in (0,SCALE)
X_points = [ [ random.random()*SCALE, random.random()*SCALE ] for i in range(FIELDSIZE) ] 

# generate an inital point S in the plain of X
S_0 = [ random.random()*SCALE, random.random()*SCALE ]

# %%
def Descent(s, X, init_step, EPSILON):
    b = beta(s, X)
    s0 = np.array(s)
    k = 1
    s_list = [s0]
    lam = init_step
    s1 = GD(s0, X, lam ,k, b)
    s_list.append(s1)
    N = Norm(P_grad(s1, X, k, b))
    Norm_list = [N]

    while N > EPSILON:
        b = beta(s1, X)
        lam = stepsize(s1, s0, X, k, b)
        s0 = s1
        s1 = GD(s0, X, lam, k, b)
        s_list.append(s1)
        N = Norm(P_grad(s1, X, k, b))
        Norm_list.append(N)
        k += 1
    
    return np.array([ s_list, Norm_list ])

# %%
TEST = Descent( S_0, X_points, 0.1, 1e-10)
# Out:
# <ipython-input-6-9a62d56d6056>:4: RuntimeWarning: invalid value encountered in double_scalars
#   return nom/denom
# <ipython-input-8-dfde80cf9b4e>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array([ s_list, Norm_list ])

# %%
TEST[0]
# Out:
# [array([17.7803636 , 13.49479444]),
#  array([-12840726.45572319, -13450763.93667459]),
#  array([ 595640.25297869, -623761.0244014 ]),
#  array([   595640.25297006, -13450763.93668363]),
#  array([   595640.25297005, -14019302.59820755]),
#  array([   595640.25297005, -14032827.22217428]),
#  array([   595640.25297005, -14045545.68854414]),
#  array([   595640.25297005, -14058251.5489947 ]),
#  array([   595640.25297005, -14070945.91647876]),
#  array([   595640.25297005, -14083628.82372662]),
#  array([   595640.25297005, -14096300.30185757]),
#  array([   595640.25297005, -14108960.38184821]),
#  array([   595640.25297005, -14121609.09453531]),
#  array([   595640.25297005, -14134246.47061671]),
#  array([   595640.25297005, -14146872.54065215]),
#  array([   595640.25297005, -14159487.33506421]),
#  array([   595640.25297005, -14172090.8841391 ]),
#  array([   595640.25297005, -14184683.21802758]),
#  array([   595640.25297005, -14197264.36674575]),
#  array([   595640.25297005, -14209834.36017592]),
#  array([   595640.25297005, -14222393.22806746]),
#  array([   595640.25297005, -14234941.00003759]),
#  array([   595640.25297005, -14247477.70557221]),
#  array([   595640.25297005, -14260003.37402675]),
#  array([   595640.25297005, -14272518.03462693]),
#  array([   595640.25297005, -14285021.71646958]),
#  array([   595640.25297005, -14297514.44852345]),
#  array([   595640.25297005, -14309996.25962997]),
#  array([   595640.25297005, -14322467.17850408]),
#  array([   595640.25297005, -14334927.23373492]),
#  array([   595640.25297005, -14347376.45378671]),
#  array([   595640.25297005, -14359814.86699943]),
#  array([   595640.25297005, -14372242.50158959]),
#  array([   595640.25297005, -14384659.38565104]),
#  array([   595640.25297005, -14397065.54715565]),
#  array([   595640.25297005, -14409461.01395407]),
#  array([   595640.25297005, -14421845.81377648]),
#  array([   595640.25297005, -14434219.97423331]),
#  array([   595640.25297005, -14446583.52281596]),
#  array([   595640.25297005, -14458936.48689752]),
#  array([   595640.25297005, -14471278.89373347]),
#  array([   595640.25297005, -14483610.77046242]),
#  array([   595640.25297005, -14495932.14410678]),
#  array([   595640.25297005, -14508243.04157345]),
#  array([   595640.25297005, -14520543.48965456]),
#  array([   595640.25297005, -14532833.51502808]),
#  array([   595640.25297005, -14545113.14425857]),
#  array([   595640.25297005, -14557382.40379782]),
#  array([   595640.25297005, -14569641.31998552]),
#  array([   595640.25297005, -14581889.91904992]),
#  array([   595640.25297005, -14594128.22710852]),
#  array([   595640.25297005, -14606356.2701687 ]),
#  array([   595640.25297005, -14618574.07412834]),
#  array([   595640.25297005, -14630781.66477654]),
#  array([   595640.25297005, -14642979.06779419]),
#  array([   595640.25297005, -14655166.30875464]),
#  array([   595640.25297005, -14667343.41312431]),
#  array([   595640.25297005, -14679510.40626335]),
#  array([   595640.25297005, -14691667.31342621]),
#  array([   595640.25297005, -14703814.15976229]),
#  array([   595640.25297005, -14715950.97031657]),
#  array([   595640.25297005, -14728077.77003014]),
#  array([   595640.25297005, -14740194.5837409 ]),
#  array([   595640.25297005, -14752301.43618409]),
#  array([   595640.25297005, -14764398.35199289]),
#  array([   595640.25297005, -14776485.35569905]),
#  array([   595640.25297005, -14788562.47173344]),
#  array([   595640.25297005, -14800629.72442661]),
#  array([   595640.25297005, -14812687.13800944]),
#  array([   595640.25297005, -14824734.73661362]),
#  array([   595640.25297005, -14836772.54427228]),
#  array([   595640.25297005, -14848800.58492055]),
#  array([   595640.25297005, -14860818.88239607]),
#  array([   595640.25297005, -14872827.46043962]),
#  array([   595640.25297005, -14884826.34269559]),
#  array([   595640.25297005, -14896815.5527126 ]),
#  array([   595640.25297005, -14908795.11394398]),
#  array([   595640.25297005, -14920765.04974838]),
#  array([   595640.25297005, -14932725.38339022]),
#  array([   595640.25297005, -14944676.13804029]),
#  array([   595640.25297005, -14956617.33677625]),
#  array([   595640.25297005, -14968549.00258315]),
#  array([   595640.25297005, -14980471.15835397]),
#  array([   595640.25297005, -14992383.82689009]),
#  array([   595640.25297005, -15004287.03090188]),
#  array([   595640.25297005, -15016180.79300912]),
#  array([   595640.25297005, -15028065.13574157]),
#  array([   595640.25297005, -15039940.08153945]),
#  array([   595640.25297005, -15051805.65275394]),
#  array([   595640.25297005, -15063661.87164764]),
#  array([   595640.25297005, -15075508.76039514]),
#  array([   595640.25297005, -15087346.34108341]),
#  array([   595640.25297005, -15099174.63571238]),
#  array([   595640.25297005, -15110993.66619534]),
#  array([   595640.25297005, -15122803.45435946]),
#  array([   595640.25297005, -15134604.02194624]),
#  array([   595640.25297005, -15146395.39061202]),
#  array([   595640.25297005, -15158177.58192841]),
#  array([   595640.25297005, -15169950.61738275]),
#  array([   595640.25297005, -15181714.5183786 ]),
#  array([   595640.25297005, -15193469.30623618]),
#  array([   595640.25297005, -15205215.00219282]),
#  array([   595640.25297005, -15216951.6274034 ]),
#  array([   595640.25297005, -15228679.20294086]),
#  array([   595640.25297005, -15240397.74979655]),
#  array([   595640.25297005, -15252107.28888074]),
#  array([   595640.25297005, -15263807.84102304]),
#  array([   595640.25297005, -15275499.42697283]),
#  array([   595640.25297005, -15287182.06739969]),
#  array([   595640.25297005, -15298855.78289383]),
#  array([   595640.25297005, -15310520.59396655]),
#  array([   595640.25297005, -15322176.52105059]),
#  array([   595640.25297005, -15333823.58450064]),
#  array([   595640.25297005, -15345461.80459366]),
#  array([   595640.25297005, -15357091.2015294 ]),
#  array([   595640.25297005, -15368711.79543072]),
#  array([   595640.25297005, -15380323.60634405]),
#  array([   595640.25297005, -15391926.65423979]),
#  array([   595640.25297005, -15403520.95901269]),
#  array([   595640.25297005, -15415106.54048229]),
#  array([   595640.25297005, -15426683.41839328]),
#  array([   595640.25297005, -15438251.61241591]),
#  array([   595640.25297005, -15449811.14214639]),
#  array([   595640.25297005, -15461362.02710727]),
#  array([   595640.25297005, -15472904.28674783]),
#  array([   595640.25297005, -15484437.94044447]),
#  array([   595640.25297005, -15495963.00750107]),
#  array([   595640.25297005, -15507479.50714942]),
#  array([   595640.25297005, -15518987.45854953]),
#  array([   595640.25297005, -15530486.88079005]),
#  array([   595640.25297005, -15541977.79288863]),
#  array([   595640.25297005, -15553460.2137923 ]),
#  array([   595640.25297005, -15564934.16237781]),
#  array([   595640.25297005, -15576399.65745202]),
#  array([   595640.25297005, -15587856.71775224]),
#  array([   595640.25297005, -15599305.36194662]),
#  array([   595640.25297005, -15610745.60863448]),
#  array([   595640.25297005, -15622177.47634667]),
#  array([   595640.25297005, -15633600.98354594]),
#  array([   595640.25297005, -15645016.14862728]),
#  array([   595640.25297005, -15656422.98991823]),
#  array([   595640.25297005, -15667821.5256793 ]),
#  array([   595640.25297005, -15679211.77410426]),
#  array([   595640.25297005, -15690593.7533205 ]),
#  array([   595640.25297005, -15701967.48138934]),
#  array([   595640.25297005, -15713332.97630643]),
#  array([   595640.25297005, -15724690.25600202]),
#  array([   595640.25297005, -15736039.33834131]),
#  array([   595640.25297005, -15747380.24112482]),
#  array([   595640.25297005, -15758712.98208864]),
#  array([   595640.25297005, -15770037.57890484]),
#  array([   595640.25297005, -15781354.04918173]),
#  array([   595640.25297005, -15792662.41046422]),
#  array([   595640.25297005, -15803962.68023412]),
#  array([   595640.25297005, -15815254.87591047]),
#  array([   595640.25297005, -15826539.01484983]),
#  array([   595640.25297005, -15837815.11434663]),
#  array([   595640.25297005, -15849083.19163346]),
#  array([   595640.25297005, -15860343.26388137]),
#  array([   595640.25297005, -15871595.34820021]),
#  array([   595640.25297005, -15882839.46163889]),
#  array([   595640.25297005, -15894075.62118573]),
#  array([   595640.25297005, -15905303.84376872]),
#  array([   595640.25297005, -15916524.14625586]),
#  array([   595640.25297005, -15927736.54545542]),
#  array([   595640.25297005, -15938941.05811626]),
#  array([   595640.25297005, -15950137.70092811]),
#  array([   595640.25297005, -15961326.49052189]),
#  array([   595640.25297005, -15972507.44346994]),
#  array([   595640.25297005, -15983680.57628638]),
#  array([   595640.25297005, -15994845.90542735]),
#  array([   595640.25297005, -16006003.44729131]),
#  array([   595640.25297005, -16017153.21821931]),
#  array([   595640.25297005, -16028295.23449529]),
#  array([   595640.25297005, -16039429.51234636]),
#  array([   595640.25297005, -16050556.06794306]),
#  array([   595640.25297005, -16061674.91739963]),
#  array([   595640.25297005, -16072786.07677432]),
#  array([   595640.25297005, -16083889.56206963]),
#  array([   595640.25297005, -16094985.3892326 ]),
#  array([   595640.25297005, -16106073.57415506]),
#  array([   595640.25297005, -16117154.1326739 ]),
#  array([   595640.25297005, -16128227.08057137]),
#  array([   595640.25297005, -16139292.43357529]),
#  array([   595640.25297005, -16150350.20735936]),
#  array([   595640.25297005, -16161400.41754337]),
#  array([   595640.25297005, -16172443.07969354]),
#  array([   595640.25297005, -16183478.20932266]),
#  array([   595640.25297005, -16194505.82189048]),
#  array([   595640.25297005, -16205525.93280385]),
#  array([   595640.25297005, -16216538.55741704]),
#  array([   595640.25297005, -16227543.71103196]),
#  array([   595640.25297005, -16238541.40889843]),
#  array([   595640.25297005, -16249531.66621442]),
#  array([   595640.25297005, -16260514.49812628]),
#  array([   595640.25297005, -16271489.91972902]),
#  array([   595640.25297005, -16282457.94606653]),
#  array([   595640.25297005, -16293418.5921318 ]),
#  array([   595640.25297005, -16304371.87286723]),
#  array([   595640.25297005, -16315317.8031648 ]),
#  array([   595640.25297005, -16326256.39786633]),
#  array([   595640.25297005, -16337187.67176374]),
#  array([   595640.25297005, -16348111.63959924]),
#  array([   595640.25297005, -16359028.31606561]),
#  array([   595640.25297005, -16369937.71580641]),
#  array([   595640.25297005, -16380839.85341618]),
#  array([   595640.25297005, -16391734.74344075]),
#  array([   595640.25297005, -16402622.40037738]),
#  array([   595640.25297005, -16413502.83867504]),
#  array([   595640.25297005, -16424376.07273461]),
#  array([   595640.25297005, -16435242.11690914]),
#  array([   595640.25297005, -16446100.98550401]),
#  array([   595640.25297005, -16456952.69277721]),
#  array([   595640.25297005, -16467797.25293954]),
#  array([   595640.25297005, -16478634.68015481]),
#  array([   595640.25297005, -16489464.98854009]),
#  array([   595640.25297005, -16500288.19216588]),
#  array([   595640.25297005, -16511104.3050564 ]),
#  array([   595640.25297005, -16521913.34118972]),
#  array([   595640.25297005, -16532715.31449801]),
#  array([   595640.25297005, -16543510.23886778]),
#  array([   595640.25297005, -16554298.12814003]),
#  array([   595640.25297005, -16565078.99611049]),
#  array([   595640.25297005, -16575852.85652985]),
#  array([   595640.25297005, -16586619.72310391]),
#  array([   595640.25297005, -16597379.60949383]),
#  array([   595640.25297005, -16608132.52931632]),
#  array([   595640.25297005, -16618878.49614386]),
#  array([   595640.25297005, -16629617.52350483]),
#  array([   595640.25297005, -16640349.62488382]),
#  array([   595640.25297005, -16651074.81372175]),
#  array([   595640.25297005, -16661793.10341607]),
#  array([   595640.25297005, -16672504.507321  ]),
#  array([   595640.25297005, -16683209.0387477 ]),
#  array([   595640.25297005, -16693906.71096445]),
#  array([   595640.25297005, -16704597.53719687]),
#  array([   595640.25297005, -16715281.53062811]),
#  array([   595640.25297005, -16725958.704399  ]),
#  array([   595640.25297005, -16736629.07160831]),
#  array([   595640.25297005, -16747292.64531286]),
#  array([   595640.25297005, -16757949.43852779]),
#  array([   595640.25297005, -16768599.46422666]),
#  array([   595640.25297005, -16779242.73534172]),
#  array([   595640.25297005, -16789879.26476401]),
#  array([   595640.25297005, -16800509.06534364]),
#  array([   595640.25297005, -16811132.14988988]),
#  array([   595640.25297005, -16821748.53117138]),
#  array([   595640.25297005, -16832358.22191637]),
#  array([   595640.25297005, -16842961.23481282]),
#  array([   595640.25297005, -16853557.5825086 ]),
#  array([   595640.25297005, -16864147.27761168]),
#  array([   595640.25297005, -16874730.33269033]),
#  array([   595640.25297005, -16885306.76027322]),
#  array([   595640.25297005, -16895876.57284967]),
#  array([   595640.25297005, -16906439.78286979]),
#  array([   595640.25297005, -16916996.40274466]),
#  array([   595640.25297005, -16927546.44484647]),
#  array([   595640.25297005, -16938089.92150876]),
#  array([   595640.25297005, -16948626.84502651]),
#  array([   595640.25297005, -16959157.22765637]),
#  array([   595640.25297005, -16969681.08161678]),
#  array([   595640.25297005, -16980198.41908818]),
#  array([   595640.25297005, -16990709.25221314]),
#  array([   595640.25297005, -17001213.59309655]),
#  array([   595640.25297005, -17011711.45380576]),
#  array([   595640.25297005, -17022202.84637077]),
#  array([   595640.25297005, -17032687.78278437]),
#  array([   595640.25297005, -17043166.27500229]),
#  array([   595640.25297005, -17053638.33494342]),
#  array([   595640.25297005, -17064103.97448989]),
#  array([   595640.25297005, -17074563.20548728]),
#  array([   595640.25297005, -17085016.03974477]),
#  array([   595640.25297005, -17095462.48903527]),
#  array([   595640.25297005, -17105902.56509562]),
#  array([   595640.25297005, -17116336.2796267 ]),
#  array([   595640.25297005, -17126763.64429361]),
#  array([   595640.25297005, -17137184.67072583]),
#  array([   595640.25297005, -17147599.37051734]),
#  array([   595640.25297005, -17158007.75522679]),
#  array([   595640.25297005, -17168409.83637768]),
#  array([   595640.25297005, -17178805.62545846]),
#  array([   595640.25297005, -17189195.1339227 ]),
#  array([   595640.25297005, -17199578.37318923]),
#  array([   595640.25297005, -17209955.35464233]),
#  array([   595640.25297005, -17220326.0896318 ]),
#  array([   595640.25297005, -17230690.58947317]),
#  array([   595640.25297005, -17241048.86544783]),
#  array([   595640.25297005, -17251400.92880315]),
#  array([   595640.25297005, -17261746.79075266]),
#  array([   595640.25297005, -17272086.46247615]),
#  array([   595640.25297005, -17282419.95511986]),
#  array([   595640.25297005, -17292747.27979657]),
#  array([   595640.25297005, -17303068.44758578]),
#  array([   595640.25297005, -17313383.46953385]),
#  array([   595640.25297005, -17323692.3566541 ]),
#  array([   595640.25297005, -17333995.11992698]),
#  array([   595640.25297005, -17344291.77030021]),
#  array([   595640.25297005, -17354582.3186889 ]),
#  array([   595640.25297005, -17364866.77597569]),
#  array([   595640.25297005, -17375145.15301089]),
#  array([   595640.25297005, -17385417.46061262]),
#  array([   595640.25297005, -17395683.70956692]),
#  array([   595640.25297005, -17405943.91062791]),
#  array([   595640.25297005, -17416198.0745179 ]),
#  array([   595640.25297005, -17426446.21192756]),
#  array([   595640.25297005, -17436688.33351598]),
#  array([   595640.25297005, -17446924.44991088]),
#  array([   595640.25297005, -17457154.57170869]),
#  array([   595640.25297005, -17467378.70947469]),
#  array([   595640.25297005, -17477596.87374314]),
#  array([   595640.25297005, -17487809.07501741]),
#  array([   595640.25297005, -17498015.32377011]),
#  array([   595640.25297005, -17508215.63044319]),
#  array([   595640.25297005, -17518410.00544811]),
#  array([   595640.25297005, -17528598.45916592]),
#  array([   595640.25297005, -17538781.00194743]),
#  array([   595640.25297005, -17548957.64411326]),
#  array([   595640.25297005, -17559128.39595407]),
#  array([   595640.25297005, -17569293.26773059]),
#  array([   595640.25297005, -17579452.26967376]),
#  array([   595640.25297005, -17589605.41198491]),
#  array([   595640.25297005, -17599752.70483579]),
#  array([   595640.25297005, -17609894.15836876]),
#  array([   595640.25297005, -17620029.78269688]),
#  array([   595640.25297005, -17630159.58790403]),
#  array([   595640.25297005, -17640283.58404504]),
#  array([   595640.25297005, -17650401.78114577]),
#  array([   595640.25297005, -17660514.18920329]),
#  array([   595640.25297005, -17670620.81818594]),
#  array([   595640.25297005, -17680721.67803346]),
#  array([   595640.25297005, -17690816.77865712]),
#  array([   595640.25297005, -17700906.12993982]),
#  array([   595640.25297005, -17710989.74173622]),
#  array([   595640.25297005, -17721067.62387282]),
#  array([   595640.25297005, -17731139.78614811]),
#  array([   595640.25297005, -17741206.23833266]),
#  array([   595640.25297005, -17751266.99016923]),
#  array([   595640.25297005, -17761322.0513729 ]),
#  array([   595640.25297005, -17771371.43163115]),
#  array([   595640.25297005, -17781415.140604  ]),
#  array([   595640.25297005, -17791453.18792411]),
#  array([   595640.25297005, -17801485.58319686]),
#  array([   595640.25297005, -17811512.33600051]),
#  array([   595640.25297005, -17821533.45588626]),
#  array([   595640.25297005, -17831548.95237839]),
#  array([   595640.25297005, -17841558.83497434]),
#  array([   595640.25297005, -17851563.11314484]),
#  array([   595640.25297005, -17861561.796334  ]),
#  array([   595640.25297005, -17871554.89395941]),
#  array([   595640.25297005, -17881542.41541225]),
#  array([   595640.25297005, -17891524.37005743]),
#  array([   595640.25297005, -17901500.7672336 ]),
#  array([   595640.25297005, -17911471.61625337]),
#  array([   595640.25297005, -17921436.92640331]),
#  array([   595640.25297005, -17931396.70694412]),
#  array([   595640.25297005, -17941350.9671107 ]),
#  array([   595640.25297005, -17951299.71611225]),
#  array([   595640.25297005, -17961242.96313239]),
#  array([   595640.25297005, -17971180.71732923]),
#  array([   595640.25297005, -17981112.9878355 ]),
#  array([   595640.25297005, -17991039.78375861]),
#  array([   595640.25297005, -18000961.11418081]),
#  array([   595640.25297005, -18010876.98815921]),
#  array([   595640.25297005, -18020787.41472594]),
#  array([   595640.25297005, -18030692.40288822]),
#  array([   595640.25297005, -18040591.96162845]),
#  array([   595640.25297005, -18050486.09990432]),
#  array([   595640.25297005, -18060374.8266489 ]),
#  array([   595640.25297005, -18070258.15077073]),
#  array([   595640.25297005, -18080136.08115393]),
#  array([   595640.25297005, -18090008.62665828]),
#  array([   595640.25297005, -18099875.79611929]),
#  array([   595640.25297005, -18109737.59834835]),
#  array([   595640.25297005, -18119594.04213278]),
#  array([   595640.25297005, -18129445.13623594]),
#  array([   595640.25297005, -18139290.88939729]),
#  array([   595640.25297005, -18149131.31033253]),
#  array([   595640.25297005, -18158966.40773366]),
#  array([   595640.25297005, -18168796.19026906]),
#  array([   595640.25297005, -18178620.66658363]),
#  array([   595640.25297005, -18188439.84529881]),
#  array([   595640.25297005, -18198253.73501271]),
#  array([   595640.25297005, -18208062.34430022]),
#  array([   595640.25297005, -18217865.68171303]),
#  array([   595640.25297005, -18227663.75577978]),
#  array([   595640.25297005, -18237456.57500613]),
#  array([   595640.25297005, -18247244.14787483]),
#  array([   595640.25297005, -18257026.48284581]),
#  array([   595640.25297005, -18266803.58835629]),
#  array([   595640.25297005, -18276575.47282084]),
#  array([   595640.25297005, -18286342.14463148]),
#  array([   595640.25297005, -18296103.61215775]),
#  array([   595640.25297005, -18305859.8837468 ]),
#  array([   595640.25297005, -18315610.96772349]),
#  array([   595640.25297005, -18325356.87239046]),
#  array([   595640.25297005, -18335097.60602819]),
#  array([   595640.25297005, -18344833.17689513]),
#  array([   595640.25297005, -18354563.59322774]),
#  array([   595640.25297005, -18364288.8632406 ]),
#  array([   595640.25297005, -18374008.99512648]),
#  array([   595640.25297005, -18383723.99705642]),
#  array([   595640.25297005, -18393433.87717981]),
#  array([   595640.25297005, -18403138.64362447]),
#  array([   595640.25297005, -18412838.30449675]),
#  array([   595640.25297005, -18422532.86788156]),
#  array([   595640.25297005, -18432222.34184251]),
#  array([   595640.25297005, -18441906.73442195]),
#  array([   595640.25297005, -18451586.05364105]),
#  array([   595640.25297005, -18461260.3074999 ]),
#  array([   595640.25297005, -18470929.50397757]),
#  array([   595640.25297005, -18480593.65103217]),
#  array([   595640.25297005, -18490252.75660099]),
#  array([   595640.25297005, -18499906.82860049]),
#  array([   595640.25297005, -18509555.87492645]),
#  array([   595640.25297005, -18519199.90345401]),
#  array([   595640.25297005, -18528838.92203774]),
#  array([   595640.25297005, -18538472.93851174]),
#  array([   595640.25297005, -18548101.96068969]),
#  array([   595640.25297005, -18557725.99636495]),
#  array([   595640.25297005, -18567345.05331061]),
#  array([   595640.25297005, -18576959.13927958]),
#  array([   595640.25297005, -18586568.26200464]),
#  array([   595640.25297005, -18596172.42919856]),
#  array([   595640.25297005, -18605771.64855412]),
#  array([   595640.25297005, -18615365.92774421]),
#  array([   595640.25297005, -18624955.2744219 ]),
#  array([   595640.25297005, -18634539.6962205 ]),
#  array([   595640.25297005, -18644119.20075365]),
#  array([   595640.25297005, -18653693.79561538]),
#  array([   595640.25297005, -18663263.48838018]),
#  array([   595640.25297005, -18672828.28660307]),
#  array([   595640.25297005, -18682388.19781967]),
#  array([   595640.25297005, -18691943.22954628]),
#  array([   595640.25297005, -18701493.38927994]),
#  array([   595640.25297005, -18711038.68449848]),
#  array([   595640.25297005, -18720579.12266063]),
#  array([   595640.25297005, -18730114.71120607]),
#  array([   595640.25297005, -18739645.45755549]),
#  array([   595640.25297005, -18749171.36911065]),
#  array([   595640.25297005, -18758692.45325448]),
#  array([   595640.25297005, -18768208.71735111]),
#  array([   595640.25297005, -18777720.16874596]),
#  array([   595640.25297005, -18787226.81476582]),
#  array([   595640.25297005, -18787226.81476582]),
#  array([nan, nan])]

# %%
S_0
# Out:
# [17.780363599386405, 13.494794438567936]

# %%
beta(S_0,X)

# %%
TEST[1]
# Out:
# [476970087.2422342,
#  1.0698726838967752e+21,
#  385931387.2766943,
#  437319319.2754342,
#  445342292.5792132,
#  452006478.6346192,
#  458535250.3698551,
#  464963100.61685514,
#  471295345.37871695,
#  477536276.69511473,
#  483689855.98179245,
#  489759760.9276956,
#  495749413.7663722,
#  501662005.749987,
#  507500518.6565034,
#  513267743.7660212,
#  518966298.6636311,
#  524598642.1675687,
#  530167087.633823,
#  535673814.84932303,
#  541120880.6936514,
#  546510228.7226006,
#  551843697.804706,
#  557123029.9233605,
#  562349877.2415498,
#  567525808.5131134,
#  572652314.9133434,
#  577730815.3522742,
#  582762661.3259839,
#  587749141.354337,
#  592691485.0476639,
#  597590866.8398223,
#  602448409.4206449,
#  607265186.8969866,
#  612042227.7082869,
#  616780517.3196468,
#  621481000.7129331,
#  626144584.6942004,
#  630772140.0337979,
#  635364503.4538083,
#  639922479.4760007,
#  644446842.1421077,
#  648938336.6171097,
#  653397680.685133,
#  657825566.1466736,
#  662222660.1250046,
#  666589606.2889211,
#  670927025.998301,
#  675235519.3783665,
#  679515666.3280386,
#  683768027.4672569,
#  687993145.0277553,
#  692191543.6913642,
#  696363731.3795931,
#  700510199.9979185,
#  704631426.1379244,
#  708727871.7401873,
#  712799984.7205604,
#  716848199.5623165,
#  720872937.8763876,
#  724874608.9318029,
#  728853610.1582298,
#  732810327.6224104,
#  736745136.480128,
#  740658401.4052277,
#  744550476.9971106,
#  748421708.1680036,
#  752272430.5112255,
#  756102970.6515809,
#  759913646.5789298,
#  763704767.965921,
#  767476636.47079,
#  771229546.026084,
#  774963783.1140987,
#  778679627.0297798,
#  782377350.131763,
#  786057218.0822265,
#  789719490.0761393,
#  793364419.0604856,
#  796992251.9439981,
#  800603229.7978879,
#  804197588.0480578,
#  807775556.6592195,
#  811337360.3113426,
#  814883218.5688132,
#  818413346.0426795,
#  821927952.5463073,
#  825427243.2448007,
#  828911418.7984579,
#  832380675.5005796,
#  835835205.409877,
#  839275196.477759,
#  842700832.670717,
#  846112294.0880551,
#  849509757.0751652,
#  852893394.3325676,
#  856263375.0208946,
#  859619864.8620116,
#  862963026.23644,
#  866293018.2772537,
#  869609996.9605999,
#  872914115.1929904,
#  876205522.895507,
#  879484367.0850568,
#  882750791.952786,
#  886004938.9398022,
#  889246946.8102866,
#  892476951.7221239,
#  895695087.2951561,
#  898901484.6771322,
#  902096272.6074841,
#  905279577.4789821,
#  908451523.3973806,
#  911612232.2391218,
#  914761823.7071679,
#  917900415.3850579,
#  921028122.7892332,
#  924145059.4197135,
#  927251336.8091851,
#  930347064.5705538,
#  933432350.4430298,
#  936507300.3368012,
#  939572018.3763359,
#  942626606.942377,
#  945671166.7126715,
#  948705796.7014803,
#  951730594.2979189,
#  954745655.3031638,
#  957751073.9665656,
#  960746943.020719,
#  963733353.7155089,
#  966710395.8511839,
#  969678157.8104824,
#  972636726.589848,
#  975586187.8297677,
#  978526625.8442533,
#  981458123.6495067,
#  984380762.991794,
#  987294624.3745455,
#  990199787.0847245,
#  993096329.21847,
#  995984327.7060558,
#  998863858.3361744,
#  1001734995.7795738,
#  1004597813.6120701,
#  1007452384.3369495,
#  1010298779.4067867,
#  1013137069.2446926,
#  1015967323.2650126,
#  1018789609.8934926,
#  1021603996.5869266,
#  1024410549.8523047,
#  1027209335.2654802,
#  1030000417.489358,
#  1032783860.2916377,
#  1035559726.562111,
#  1038328078.3295267,
#  1041088976.7780476,
#  1043842482.2632991,
#  1046588654.328033,
#  1049327551.7174026,
#  1052059232.3938835,
#  1054783753.5518183,
#  1057501171.6316371,
#  1060211542.3337206,
#  1062914920.6319504,
#  1065611360.7869334,
#  1068300916.3589216,
#  1070983640.2204319,
#  1073659584.5685705,
#  1076328800.9370813,
#  1078991340.2081144,
#  1081647252.6237235,
#  1084296587.7971125,
#  1086939394.7236228,
#  1089575721.7914734,
#  1092205616.792266,
#  1094829126.9312563,
#  1097446298.8373916,
#  1100057178.573143,
#  1102661811.6441073,
#  1105260243.008409,
#  1107852517.0858955,
#  1110438677.767138,
#  1113018768.4222329,
#  1115592831.909425,
#  1118160910.5835347,
#  1120723046.304225,
#  1123279280.4440765,
#  1125829653.896503,
#  1128374207.0835013,
#  1130912979.9632432,
#  1133446012.0375028,
#  1135973342.3589354,
#  1138495009.538214,
#  1141011051.751006,
#  1143521506.7448263,
#  1146026411.8457363,
#  1148525803.9649172,
#  1151019719.6051104,
#  1153508194.8669298,
#  1155991265.4550464,
#  1158468966.684254,
#  1160941333.485416,
#  1163408400.4112911,
#  1165870201.6422536,
#  1168326770.9918969,
#  1170778141.9125273,
#  1173224347.5005605,
#  1175665420.5018048,
#  1178101393.316653,
#  1180532298.005168,
#  1182958166.2920759,
#  1185379029.5716672,
#  1187794918.9126027,
#  1190205865.0626302,
#  1192611898.453215,
#  1195013049.2040849,
#  1197409347.1276884,
#  1199800821.733577,
#  1202187502.2327008,
#  1204569417.54163,
#  1206946596.2866983,
#  1209319066.8080733,
#  1211686857.163752,
#  1214049995.133483,
#  1216408508.2226245,
#  1218762423.6659298,
#  1221111768.4312615,
#  1223456569.2232516,
#  1225796852.4868853,
#  1228132644.4110327,
#  1230463970.931911,
#  1232790857.7364862,
#  1235113330.265825,
#  1237431413.7183826,
#  1239745133.0532293,
#  1242054512.9932356,
#  1244359578.0281892,
#  1246660352.4178643,
#  1248956860.195043,
#  1251249125.1684856,
#  1253537170.9258354,
#  1255821020.8365018,
#  1258100698.0544748,
#  1260376225.521099,
#  1262647625.9678016,
#  1264914921.9187775,
#  1267178135.693633,
#  1269437289.4099703,
#  1271692404.9859529,
#  1273943504.142815,
#  1276190608.4073331,
#  1278433739.1142545,
#  1280672917.4087002,
#  1282908164.2485085,
#  1285139500.4065597,
#  1287366946.4730587,
#  1289590522.8577716,
#  1291810249.7922394,
#  1294026147.3319566,
#  1296238235.3585021,
#  1298446533.5816588,
#  1300651061.541475,
#  1302851838.6103165,
#  1305048883.994872,
#  1307242216.7381344,
#  1309431855.7213519,
#  1311617819.6659448,
#  1313800127.1353965,
#  1315978796.5371215,
#  1318153846.1242857,
#  1320325293.997625,
#  1322493158.107221,
#  1324657456.254247,
#  1326818206.0927017,
#  1328975425.1311064,
#  1331129130.734179,
#  1333279340.1244893,
#  1335426070.384076,
#  1337569338.456061,
#  1339709161.1462185,
#  1341845555.124534,
#  1343978536.9267395,
#  1346108122.955822,
#  1348234329.4835122,
#  1350357172.6517572,
#  1352476668.4741592,
#  1354592832.837409,
#  1356705681.5026872,
#  1358815230.1070514,
#  1360921494.1648023,
#  1363024489.0688295,
#  1365124230.0919392,
#  1367220732.3881698,
#  1369314010.994068,
#  1371404080.82998,
#  1373490956.7012913,
#  1375574653.299673,
#  1.2835388671327909e+103,
#  1.0875452389313841e+104,
#  3.8341936382295864e+104,
#  1.0981489565170354e+105,
#  2.85790538832302e+105,
#  7.037015247573745e+105,
#  1.6712449081051497e+106,
#  3.8693815265155516e+106,
#  8.790974445128213e+106,
#  1.968325135296822e+107,
#  4.356291395804359e+107,
#  9.550635599256096e+107,
#  2.0774936313671137e+108,
#  4.489235828895845e+108,
#  9.64600707169239e+108,
#  2.0625175813732857e+109,
#  4.391288486803991e+109,
#  9.314331185213203e+109,
#  1.96906769788715e+110,
#  4.150241745868591e+110,
#  8.724107377297517e+110,
#  1.8294293477132218e+111,
#  3.8278423289647547e+111,
#  8.012812746177563e+111,
#  1.7328694545555422e+112,
#  3.725989373403997e+112,
#  7.971758193033447e+112,
#  1.6981642653085248e+113,
#  3.6036693027052155e+113,
#  7.711077478357451e+113,
#  1.6642114706700418e+114,
#  3.5781884616759073e+114,
#  7.860903779413962e+114,
#  1.7314979630509878e+115,
#  3.7811941812446735e+115,
#  8.197918668468643e+115,
#  1.7712536998514163e+116,
#  3.870755785768028e+116,
#  8.500840669937301e+116,
#  1.8616720593201826e+117,
#  4.0803126450527704e+117,
#  8.873605305142094e+117,
#  1.9171269704106533e+118,
#  4.118688174131064e+118,
#  8.805494799498807e+118,
#  1.8745736686918242e+119,
#  3.975800814464014e+119,
#  8.404320712673267e+119,
#  1.7712911786503216e+120,
#  3.7232044409583224e+120,
#  7.807192192343721e+120,
#  1.6360316634812699e+121,
#  3.43106748417134e+121,
#  7.179741793613978e+121,
#  1.4993899594904172e+122,
#  3.125504649330702e+122,
#  6.504143910726427e+122,
#  1.3535202781040328e+123,
#  2.81745882416524e+123,
#  5.855482552723288e+123,
#  1.215155520621441e+124,
#  2.518321824111661e+124,
#  5.223254674041791e+124,
#  1.0846019887038915e+125,
#  2.251153513806038e+125,
#  4.670389979199209e+125,
#  9.691151910258855e+125,
#  2.0082207606881322e+126,
#  4.156255331676504e+126,
#  8.591806521716245e+126,
#  1.7741545472657185e+127,
#  3.659764560260887e+127,
#  7.554570724346175e+127,
#  1.5583079711679354e+128,
#  3.2112934123274437e+128,
#  6.6117227846804864e+128,
#  1.3601282284787914e+129,
#  2.7957373031758305e+129,
#  5.742264388413086e+129,
#  1.1785766661939185e+130,
#  2.417332997813793e+130,
#  4.954890347200213e+130,
#  1.0153365966396429e+131,
#  2.081528339655531e+131,
#  4.264653910712768e+131,
#  8.73227754863539e+131,
#  1.7870047835936135e+132,
#  3.6550193177472916e+132,
#  7.471881624070138e+132,
#  1.5267098347600774e+133,
#  3.11945003765072e+133,
#  6.375101821640648e+133,
#  1.302284866725721e+134,
#  2.6617691313381253e+134,
#  5.440734669737744e+134,
#  1.1121052380255276e+135,
#  2.272075961147549e+135,
#  4.639781256353577e+135,
#  9.47061911669506e+135,
#  1.9322949718496516e+136,
#  3.9408523714426926e+136,
#  8.034070804623335e+136,
#  1.6372558016499522e+137,
#  3.3353321126378583e+137,
#  6.792180438091708e+137,
#  1.3827145149641534e+138,
#  2.813936543952108e+138,
#  5.7247900105333665e+138,
#  1.1643218794808931e+139,
#  2.3673327259752174e+139,
#  4.811966258808206e+139,
#  9.77838076952573e+139,
#  1.986535308313294e+140,
#  4.034847361913589e+140,
#  8.198416274964101e+140,
#  1.6654023242133185e+141,
#  3.382192592485883e+141,
#  6.867061255681556e+141,
#  1.3939276156476077e+142,
#  2.829605438480003e+142,
#  5.744584105577862e+142,
#  1.1663206579738498e+143,
#  2.3681038408600196e+143,
#  4.807064810568128e+143,
#  9.755708799411299e+143,
#  1.979430730570527e+144,
#  4.0153859725536696e+144,
#  8.14371470435888e+144,
#  1.6513103578845188e+145,
#  3.3477135146586933e+145,
#  6.785529020941828e+145,
#  1.3751095739454425e+146,
#  2.7861936130946645e+146,
#  5.644270371632092e+146,
#  1.1432176185686118e+147,
#  2.3160595274652506e+147,
#  4.691628070039415e+147,
#  9.502166517329411e+147,
#  1.9250175840859997e+148,
#  3.899224556010839e+148,
#  7.896739474539551e+148,
#  1.5989883806682022e+149,
#  3.237222748310263e+149,
#  6.552867879232977e+149,
#  1.3262442086998801e+150,
#  2.6838021438793912e+150,
#  inf,
#  nan]

# %%
Norm(np.array([3.34925418e+19, 3.40957974e+19]))
# Out:
# 4.779407658451614e+19

# %%
min(TEST[1])
# Out:
# 15495236.68030372

# %%
TEST[0]
# Out:
# [array([55.46351128, 43.23950762]),
#  array([-1451068.93123418, -1892505.29889845]),
#  array([-69049.49961275, -90075.08936501]),
#  array([52.64123141, 47.94606498]),
#  array([-62102.27050427, -67130.07206428]),
#  array([-56658.25742519, -61246.09605805]),
#  array([52.64123141, 47.94606498]),
#  array([-55443.07035775, -59932.70252906]),
#  array([-54854.79885536, -59296.88932382]),
#  array([52.64123141, 47.94606498]),
#  array([-54709.67453492, -59140.03664748]),
#  array([-54637.39967545, -59061.92082873]),
#  array([52.64123142, 47.94606499]),
#  array([-54619.36075479, -59042.42408539]),
#  array([-54610.3457585 , -59032.68053388]),
#  array([52.64123128, 47.94606484]),
#  array([-54608.09254766, -59030.24507986]),
#  array([-54606.96597505, -59029.02746224]),
#  array([52.6412319 , 47.94606551]),
#  array([-54606.68400666, -59028.7233733 ]),
#  array([-54606.5431898 , -59028.57117619]),
#  array([52.64124164, 47.94607604]),
#  array([-54606.50277713, -59028.53794612]),
#  array([-54606.48517509, -59028.51892156]),
#  array([52.64120672, 47.94603829]),
#  array([-54606.49945293, -59028.4968837 ]),
#  array([-54606.49725268, -59028.49450564]),
#  array([52.64141104, 47.94625913]),
#  array([-54606.38742613, -59028.59501634]),
#  array([-54606.3871511 , -59028.59471908]),
#  array([52.6379407 , 47.94250832]),
#  array([-54608.24292693, -59026.87746476]),
#  array([-54608.24289255, -59026.87742761]),
#  array([52.67580405, 47.98342941]),
#  array([-54587.97508421, -59045.61795441]),
#  array([-54587.97507991, -59045.61794976]),
#  array([52.29375232, 47.57026801]),
#  array([-54790.54391089, -58857.01719526]),
#  array([-54790.54391036, -58857.01719468]),
#  array([53.35062967, 48.70800246]),
#  array([-54224.95540484, -59373.6441017 ]),
#  array([-54224.95540478, -59373.64410163]),
#  array([55.7804881 , 51.38283513]),
#  array([-53026.31759364, -60425.71524708]),
#  array([-53026.31759364, -60425.71524707]),
#  array([170.69990052, 182.45209389]),
#  array([-41923.99482382, -67346.44017024]),
#  array([-41923.99482382, -67346.44017024]),
#  array([30223.34839611, 48487.66117155]),
#  array([  -201.60916914, -77427.82015388]),
#  array([  -201.60916914, -77427.82015388]),
#  array([nan, nan])]

# %%
x_ax = [X_points[i][0] for i in range(len(X_points))]
y_ax = [X_points[i][1] for i in range(len(X_points))]
plt.scatter(x_ax, y_ax, c ='y')
plt.scatter(TEST[0][-3][0],TEST[0][-3][1], c = 'b' )
plt.show()

# %%
TEST[0][-1]
# Out:
# array([289.60201268, 302.57110591])

# %%
P_grad(TEST[0][-1], X_points, 1)
# Out:
# array([48557.52865815, 51095.37592916])

# %%
TEST[0][0][0]
# Out:
# 5

# %%
x0 = np.array([5,5])
EPSILON = 1e-10
k = 1
# x0 = np.array([random.randrange(1,20), random.randrange(0,20)])
print("x:", x0)
print("Gradient", P_grad(x0,k))
lam = 0.1 #random.random() + 1e-12
print('stepsize:',lam)
x1 = GD(x0, lam,k)
print("x:", x1)
print("Gradient", P_grad(x1,k))
N = Norm(x1 - x0)
print("Squared Norm:",N)
while N > EPSILON:
    lam = stepsize(x1,x0, k)
    print("stepsize:", lam)
    x0 = x1
    x1 = GD(x0, lam, k)
    print("x:", x1)
    print("Gradient", P_grad(x1,k))
    k += 1
    print("k=", k)
    N = Norm(x1 - x0)
    print("Squared Norm:",N)
# Out:
# x: [5 5]
# Gradient [11  9]
# stepsize: 0.1
# x: [3.9 4.1]
# Gradient [8.8 7.2]
# Squared Norm: 1.42126704035519
# stepsize: 0.5000000000000002
# x: [-0.5  0.5]
# Gradient [-3.00000000e+00 -3.55271368e-15]
# k= 2
# Squared Norm: 5.6850681614207605
# stepsize: 0.33608978145304175
# x: [1.51653869 0.5       ]
# Gradient [ 4.03307738e+00 -1.11022302e-15]
# k= 3
# Squared Norm: 2.016538688718255
# stepsize: 0.1257736516357206
# x: [1.00928382 0.5       ]
# Gradient [ 3.01856764e+00 -7.77156117e-16]
# k= 4
# Squared Norm: 0.5072548690896048
# stepsize: 0.5
# x: [-0.5  0.5]
# Gradient [-24.   0.]
# k= 5
# Squared Norm: 1.509283819628648
# stepsize: 0.02958303005095145
# x: [0.91998544 0.5       ]
# Gradient [0.27950504 0.        ]
# k= 6
# Squared Norm: 1.4199854424456697
# stepsize: 0.015151515151515152
# x: [0.95454545 0.5       ]
# Gradient [2.66453526e-15 0.00000000e+00]
# k= 7
# Squared Norm: 0.034560012099784876
# stepsize: 0.007692307692307694
# x: [0.97692308 0.5       ]
# Gradient [-3.55271368e-15  0.00000000e+00]
# k= 8
# Squared Norm: 0.022377622377622308
# stepsize: 0.003875968992248062
# x: [0.98837209 0.5       ]
# Gradient [-5.32907052e-15  0.00000000e+00]
# k= 9
# Squared Norm: 0.0114490161001789
# stepsize: 0.0019455252918287938
# x: [0.99416342 0.5       ]
# Gradient [1.0658141e-14 0.0000000e+00]
# k= 10
# Squared Norm: 0.005791331101257846
# stepsize: 0.0009746588693957116
# x: [0.99707602 0.5       ]
# Gradient [2.84217094e-14 0.00000000e+00]
# k= 11
# Squared Norm: 0.002912599267299254
# stepsize: 0.0004878048780487805
# x: [0.99853659 0.5       ]
# Gradient [-2.66453526e-15  0.00000000e+00]
# k= 12
# Squared Norm: 0.0014605619740407638
# stepsize: 0.00024402147388970225
# x: [0.99926794 0.5       ]
# Gradient [1.70530257e-13 0.00000000e+00]
# k= 13
# Squared Norm: 0.0007313502124772775
# stepsize: 0.000122040517451794
# x: [0.99963388 0.5       ]
# Gradient [1.0658141e-14 0.0000000e+00]
# k= 14
# Squared Norm: 0.0003659428693136846
# stepsize: 6.102770657878677e-05
# x: [0.99981692 0.5       ]
# Gradient [8.8817842e-16 0.0000000e+00]
# k= 15
# Squared Norm: 0.00018303843261902042
# stepsize: 3.0515715593530668e-05
# x: [0.99990845 0.5       ]
# Gradient [-6.82121026e-13  0.00000000e+00]
# k= 16
# Squared Norm: 9.153597295574745e-05
# stepsize: 1.525832341542311e-05
# x: [0.99995423 0.5       ]
# Gradient [-8.52651283e-14  0.00000000e+00]
# k= 17
# Squared Norm: 4.577217653434218e-05
# stepsize: 7.629278117704503e-06
# x: [0.99997711 0.5       ]
# Gradient [-1.0658141e-14  0.0000000e+00]
# k= 18
# Squared Norm: 2.288713589315705e-05
# stepsize: 3.814668162016586e-06
# x: [0.99998856 0.5       ]
# Gradient [-1.33226763e-15  0.00000000e+00]
# k= 19
# Squared Norm: 1.1443829867063826e-05
# stepsize: 1.9073413568826414e-06
# x: [0.99999428 0.5       ]
# Gradient [-1.45519152e-11  0.00000000e+00]
# k= 20
# Squared Norm: 5.721980415374084e-06
# stepsize: 9.536724974203157e-07
# x: [0.99999714 0.5       ]
# Gradient [1.09139364e-11 0.00000000e+00]
# k= 21
# Squared Norm: 2.8610065784251404e-06
# stepsize: 4.7683670345620785e-07
# x: [0.99999857 0.5       ]
# Gradient [2.72848411e-12 0.00000000e+00]
# k= 22
# Squared Norm: 1.430507381883217e-06
# stepsize: 2.38418465414779e-07
# x: [0.99999928 0.5       ]
# Gradient [6.82121026e-13 0.00000000e+00]
# k= 23
# Squared Norm: 7.15254714123148e-07
# stepsize: 1.192092611290786e-07
# x: [0.99999964 0.5       ]
# Gradient [1.70530257e-13 0.00000000e+00]
# k= 24
# Squared Norm: 3.576276128569589e-07
# stepsize: 5.9604637669964114e-08
# x: [0.99999982 0.5       ]
# Gradient [4.26325641e-14 0.00000000e+00]
# k= 25
# Squared Norm: 1.7881387037732566e-07
# stepsize: 2.980232061133858e-08
# x: [0.99999991 0.5       ]
# Gradient [1.0658141e-14 0.0000000e+00]
# k= 26
# Squared Norm: 8.940695117587438e-08
# stepsize: 1.4901160749758461e-08
# x: [0.99999996 0.5       ]
# Gradient [2.66453526e-15 0.00000000e+00]
# k= 27
# Squared Norm: 4.470347958474008e-08
# stepsize: 7.4505804859015265e-09
# x: [0.99999998 0.5       ]
# Gradient [8.8817842e-16 0.0000000e+00]
# k= 28
# Squared Norm: 2.2351740791570762e-08
# stepsize: 3.7252902707063384e-09
# x: [0.99999999 0.5       ]
# Gradient [7.4505806e-09 0.0000000e+00]
# k= 29
# Squared Norm: 1.1175870673341137e-08
# stepsize: 1.8626451422920633e-09
# x: [0.99999999 0.5       ]
# Gradient [-1.11758709e-08  0.00000000e+00]
# k= 30
# Squared Norm: 5.587935336670569e-09
# stepsize: 9.313225728807549e-10
# x: [1.  0.5]
# Gradient [-5.58793545e-09  0.00000000e+00]
# k= 31
# Squared Norm: 2.7939677238464355e-09
# stepsize: 4.656612868740584e-10
# x: [1.  0.5]
# Gradient [-2.79396772e-09  0.00000000e+00]
# k= 32
# Squared Norm: 1.3969838619232178e-09
# stepsize: 2.328306435454494e-10
# x: [1.  0.5]
# Gradient [-1.39698386e-09  0.00000000e+00]
# k= 33
# Squared Norm: 6.984919309616089e-10
# stepsize: 1.1641532179982976e-10
# x: [1.  0.5]
# Gradient [-6.98491931e-10  0.00000000e+00]
# k= 34
# Squared Norm: 3.4924596548080444e-10
# stepsize: 5.8207660906691144e-11
# x: [1.  0.5]
# Gradient [-3.49245965e-10  0.00000000e+00]
# k= 35
# Squared Norm: 1.7462298274040222e-10
# stepsize: 2.9103830455039638e-11
# x: [1.  0.5]
# Gradient [-1.74622983e-10  0.00000000e+00]
# k= 36
# Squared Norm: 8.731149137020111e-11

# %%
Norm([5.12295895e-09, 1.79508469e-01])**2
# Out:
# 0.03222329044272399

# %% [markdown]
# # OLD CODE

# %% [markdown]
# ## Failed $\log$ barrier penalty method algorithm

# %%
def obj_func(x): return x[0]**2 + x[1]**2 + x[0] - x[1]
def Gs(x):
    g1, g2 = 1 - x[0] , -x[1]
    return np.array([g1,g2])
def P(x,k):
    return obj_func(x) - (1/k)*np.log(-Gs(x))
def P_grad(x,k):
    p1 = 2*x[0] + 1 + 1/(k*(1-x[0]))
    p2 = 2*x[1] -1 + 1/(k*x[1])
    return np.array([p1,p2])

# %%
# testing
def obj_func(x): return x[0]**2 + x[1]**2 + x[0] - x[1]

# %%
def Gs(x):
    g1, g2 = 1 - x[0] , -x[1]
    return np.array([g1,g2])

# %%
pre_lim_x_test = np.array([2,1.5])
print(obj_func(pre_lim_x_test))
Gs(pre_lim_x_test)

# %%
def P(x,k):
    return obj_func(x) - (1/k)*np.log(-Gs(x))

# %%
(1/k)*np.log(Gs(x1))

# %%
def P_grad(x,k):
    p1 = 2*x[0] + 1 + 1/(k*(1-x[0]))
    p2 = 2*x[1] -1 + 1/(k*x[1])
    return np.array([p1,p2])

# %%
P_grad(pre_lim_x_test,1)

# %%
def Norm(x): return np.linalg.norm(x)

def stepsize(x1, x0,k):
    nom = np.dot(x1 - x0, P_grad(x1,k) - P_grad(x0,k))
    denom = np.linalg.norm( P_grad(x1,k) - P_grad(x0,k) )**2
    return nom/denom

def GD(x, lam ,k):
    return x - lam*P_grad(x,k)

# %%
x = pre_lim_x_test
EPSILON = 1e-3
k = 1
# x0 = np.array([random.randrange(1,20), random.randrange(0,20)])
x0 = x
print("x:", x0)
print("Gradient", P_grad(x0,k))
lam = random.random() + 1e-12

# %%
(1/k)*np.log(Gs(x0))

# %%
Gs(x0)

# %%
x1 = GD(x0, lam,k)
print("x:", x1)
print("Gradient", P_grad(x1,k))
N = Norm(P_grad(x,k))
print("Squared Norm:",N)

# %%
Norm(P_grad([1.0000000001,0.0000000001],k))

# %%
while N > EPSILON:
    lam = stepsize(x1,x0, k)
    print("stepsize:", lam)
    x0 = x1
    x1 = GD(x0, lam, k)
    print("x:", x1)
    print("Gradient", P_grad(x1,k))
    k += 1
    N = Norm(P_grad(x,k))
    print("Squared Norm:",N)

# %%
k

# %%
FIELDSIZE = 100
NUM_X = 100

X = []

for i in range(FIELDSIZE):
    x_i = np.array([random.randrange(-FIELDSIZE, FIELDSIZE), random.randrange(-FIELDSIZE, FIELDSIZE)])
    X.append(x_i)

# %%
random.random()*100
# Out:
# 87.18373729622067

# %% [markdown]
# Useful code

# %%
S = np.array([random.randrange(-FIELDSIZE, FIELDSIZE), random.randrange(-FIELDSIZE, FIELDSIZE)])
S_data = [S]

def norm_func(s, x):
    return (s[0] - x[0])**2 + (s[1] - x[1])**2

norms = []
for x in X:
    norms.append(norm(S,x))

alpha_index = np.argmax(norms)
alpha = norms[alpha_index]

# %%
lambdas = [0]*len(X)

def obj(s):
    obj_norms = []
    for x in X:
        obj_norms.append(norm(S,x))
    return sum(obj_norms) + alpha

# %%
def conditions(s):
    g = [0]*len(X)
    for i in range(len(X)):
        g[i] = norm(s, X[i]) - alpha
    return g

# %% [markdown]
# Useful code

# %%
def lagrange(s):
    G = conditions(s)
    lambda_gs = [0]*len(X)
    for i in range(len(X)):
        lambda_gs[i] = lambdas[i]*G[i]
    return obj(s) + sum(lambda_gs)

# %%
lagrange(S)

# %%
obj(S)

# %%
def grad_lagrange(s):
    gradL = [0, 0]
    for i in range(len(X)):
        gradL[0] += 2*(1+lambdas[i])*(s[0]-X[i][0])
        gradL[1] += 2*(1+lambdas[i])*(s[1]-X[i][1])
    return np.array(gradL)

# %%
G = conditions(S)
G[alpha_index]

# %%
def grad_gl(s):
    gradgL = [0,0]
    for i in range(len(X)):
        gradgL[0] += 2*(s[0] - X[i][0])
        gradgL[1] += 2*(s[1] - X[i][1])
    return np.array(gradgL)

# %%
def Real_norm(s): return np.linalg.norm(s)

# %%
def step(lambdaa):
    return lambdaa - STEPSIZE*grad_gl(S)

# %%
def Backtrack(l1, l2):
    STEPSIZE = np.dot(l2 - l1, 2*(S - ))

# %%
teste = []
L1 = random.randrange(1e6)
L2 = L1 - 5
while Real_norm(grad_lagrange(S)) > 10:
    STEPSIZE = Backtrack(L1, L2)
    lambdas[alpha_index]  = step(lambdas[alpha_index])
    teste.append(lambdas[alpha_index])

# %%
plt.plot(range(len(teste)), teste)
plt.show

# %%
teste[-1]

# %%
teste[0]

# %%
Real_norm(S - np.array(grad_lagrange(S)))

# %%
grad_lagrange(S)

# %%
grad_lagrange(S - 10 * np.array(grad_lagrange(S)))

# %%
STEPSIZE

# %%
random.randrange(1e6)
